# %%
# %autosave 30
# %reload_ext autoreload
# Out:
# Autosaving every 30 seconds

# %% [markdown]
# # Imports

# %%
import xarray as xr
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Data Analysis

# %%
ds = xr.open_dataset('data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc')
df = ds.to_dataframe()


print(df.head())
print(df.columns)
print(df.size)

# Export df into csv
df.to_csv('data/KMDS__OPER_P___10M_OBS_L2_202402132020.csv')
# Out:
#                                          wsi stationname      lat     lon  \
# station time
# 06201   2024-02-13 20:20:00  0-20000-0-06201    D15-FA-1  54.3256  2.9358
# 06203   2024-02-13 20:20:00  0-20000-0-06203       P11-B  52.3600  3.3417
# 06204   2024-02-13 20:20:00  0-20000-0-06204   K14-FA-1C  53.2694  3.6278
# 06205   2024-02-13 20:20:00  0-20000-0-06205     A12-CPP  55.3992  3.8103
# 06207   2024-02-13 20:20:00  0-20000-0-06207     L9-FF-1  53.6144  4.9603
#
#                              height  D1H     dd     dn  dr   dsd  ...  W10  \
# station time                                                      ...
# 06201   2024-02-13 20:20:00   42.70  NaN  215.8  144.8 NaN  19.2  ...  5.0
# 06203   2024-02-13 20:20:00   41.84  NaN  184.7  158.9 NaN   8.6  ...  6.0
# 06204   2024-02-13 20:20:00   41.80  NaN  179.8  168.8 NaN   3.9  ...  6.0
# 06205   2024-02-13 20:20:00   48.35  NaN  215.1  201.1 NaN   2.8  ...  0.0
# 06207   2024-02-13 20:20:00   45.31  NaN  192.7  185.6 NaN   2.2  ...  5.0
#
#                              W10-10    ww  ww-10       zm  iso_dataset  \
# station time
# 06201   2024-02-13 20:20:00     5.0  51.0   51.0  14400.0          b''
# 06203   2024-02-13 20:20:00     6.0  58.0   62.0   3070.0          b''
# 06204   2024-02-13 20:20:00     5.0  58.0   51.0  10600.0          b''
# 06205   2024-02-13 20:20:00     0.0   2.0    2.0  18300.0          b''
# 06207   2024-02-13 20:20:00     5.0  52.0   52.0  14000.0          b''
#
#                              product  projection  nhc   za
# station time
# 06201   2024-02-13 20:20:00      b''         b''  b''  b''
# 06203   2024-02-13 20:20:00      b''         b''  b''  b''
# 06204   2024-02-13 20:20:00      b''         b''  b''  b''
# 06205   2024-02-13 20:20:00      b''         b''  b''  b''
# 06207   2024-02-13 20:20:00      b''         b''  b''  b''
#
# [5 rows x 101 columns]
# Index(['wsi', 'stationname', 'lat', 'lon', 'height', 'D1H', 'dd', 'dn', 'dr',
#        'dsd',
#        ...
#        'W10', 'W10-10', 'ww', 'ww-10', 'zm', 'iso_dataset', 'product',
#        'projection', 'nhc', 'za'],
#       dtype='object', length=101)
# 6969

# %%
# Print global attributes
print("Global Attributes:")
for attr in ds.attrs:
    print(f"{attr}: {ds.attrs[attr]}")

# Print variable attributes
print("\nVariable Attributes:")
for var in ds.variables:
    print(f"{var} Attributes:")
    for attr in ds.variables[var].attrs:
        print(f"  {attr}: {ds.variables[var].attrs[attr]}")

# Print encoding information (useful for saving back to NetCDF)
print("\nEncoding:")
for var in ds.variables:
    print(f"{var} Encoding: {ds.variables[var].encoding}")
# Out:
# Global Attributes:
# featureType: timeSeries
# Conventions: CF-1.4
# title: KMDS__OPER_P___10M_OBS_L2
# institution: Royal Netherlands Meteorological Institute (KNMI)
# source: Royal Netherlands Meteorological Institute (KNMI)
# history: File created from KNMI's Meteorological Data Distribution System (KMDS).
# references: https://dataplatform.knmi.nl
# comment: Sensor set-ups at 'Platform/AWS' sites deviate from land AWS sites, resulting in different sensor elevations. Similarly, sensor set-ups at 'Mistposten' serve specific aviation-purposes and they do not meet all WMO recommendations for surface observing stations on land.
#
# Variable Attributes:
# station Attributes:
#   long_name: Station id
#   cf_role: timeseries_id
# time Attributes:
#   long_name: time of measurement
#   standard_name: time
# wsi Attributes:
#   long_name: Station wsi
# stationname Attributes:
#   long_name: Station name
# lat Attributes:
#   long_name: station  latitude
#   standard_name: latitude
#   units: degrees_north
# lon Attributes:
#   long_name: station longitude
#   standard_name: longitude
#   units: degrees_east
# height Attributes:
#   long_name: Station height
#   standard_name: height
#   units: m
# D1H Attributes:
#   standard_name: rainfall_duration
#   units: min
#   long_name: Rainfall Duration in last Hour
# dd Attributes:
#   standard_name: wind_from_direction
#   units: degree
#   long_name: Wind Direction 10 Min Average with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# dn Attributes:
#   standard_name: wind_from_direction
#   units: degree
#   long_name: Wind Direction Sensor 10 Min Minimum with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# dr Attributes:
#   standard_name: precipitation_duration
#   units: sec
#   long_name: Precipitation Duration (Rain Gauge) 10 Min Sum
# dsd Attributes:
#   standard_name: wind_from_direction
#   units: degree
#   long_name: Wind Direction 10 Min Std Dev with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# dx Attributes:
#   standard_name: wind_from_direction
#   units: degree
#   long_name: Wind Direction Sensor 10 Min Maximum with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# ff Attributes:
#   standard_name: wind_speed
#   units: m s-1
#   long_name: Wind Speed at 10m 10 Min Average with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# ffs Attributes:
#   standard_name: wind_speed_sensor_10_min_average
#   units: m s-1
#   long_name: Wind Speed Sensor 10 Min Average with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# fsd Attributes:
#   standard_name: wind_speed_10_min_std_dev
#   units: m s-1
#   long_name: Wind Speed 10 Min Std Dev with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# fx Attributes:
#   standard_name: wind_gust_at_10m_maximum_last_10_min_interval
#   units: m s-1
#   long_name: Wind Gust at 10m Maximum last 10 Min Interval
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# fxs Attributes:
#   standard_name: wind_gust_sensor_maximum_last_10_min_interval
#   units: m s-1
#   long_name: Wind Gust Sensor Maximum last 10 Min Interval
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# gff Attributes:
#   standard_name: wind_speed_of_gust
#   units: m s-1
#   long_name: Wind Gust at 10m 10 Min Maximum with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# gffs Attributes:
#   standard_name: wind_speed_of_gust
#   units: m s-1
#   long_name: Wind Gust Sensor 10 Min Maximum with MD
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# h Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base
# h1 Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base First Layer
# h2 Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base Second Layer
# h3 Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base Third Layer
# hc Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base Ceilometer Algorithm
# hc1 Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base Ceilometer First Layer
# hc2 Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base Ceilometer Second Layer
# hc3 Attributes:
#   standard_name: cloud_base_altitude
#   units: ft
#   long_name: Cloud Base Ceilometer Third Layer
# n Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Total cloud cover
# n1 Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Cloud Amount First Layer
# n2 Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Cloud Amount Second Layer
# n3 Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Cloud Amount Third Layer
# nc Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Total Cloud Cover Ceilometer
# nc1 Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Cloud Amount Ceilometer First Layer
# nc2 Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Cloud Amount Ceilometer Second Layer
# nc3 Attributes:
#   standard_name: cloud_cover
#   units: octa
#   long_name: Cloud Amount Ceilometer Third Layer
# p0 Attributes:
#   standard_name: air_pressure_at_station_level
#   units: hPa
#   long_name: Air Pressure at Station Level 1 Min Average
# pp Attributes:
#   standard_name: air_pressure_at_sea_level
#   units: hPa
#   long_name: Air Pressure at Sea Level 1 Min Average
# pg Attributes:
#   standard_name: lwe_precipitation_rate
#   units: mm h-1
#   long_name: Precipitation Intensity (PWS) 10 Min Average
#   comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# pr Attributes:
#   standard_name: precipitation_duration
#   units: sec
#   long_name: Precipitation Duration (PWS) 10 Min Sum
#   comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# ps Attributes:
#   standard_name: air_pressure_at_sensor_level
#   units: hPa
#   long_name: Air Pressure at Sensor Level 1 Min Average
# pwc Attributes:
#   standard_name: present_weather
#   units: code
#   long_name: Corrected Precipitation Type 10 Min Maximum
#   comment: KNMI: Handboek waarnemingen. 5.3 PW-code neerslagsoort. https://www.knmi.nl/kennis-en-datacentrum/publicatie/handboek-waarnemingen. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# Q1H Attributes:
#   standard_name: global_radiation
#   units: J cm-2
#   long_name: Global Radiation 1 Hour Sum
# Q24H Attributes:
#   standard_name: global_radiation
#   units: J cm-2
#   long_name: Global Radiation 24 Hour Sum
# qg Attributes:
#   standard_name: total_downwelling_shortwave_flux_in_air
#   units: W m-2
#   long_name: Global Solar Radiation 10 Min Average
# qgn Attributes:
#   standard_name: global_solar_radiation
#   units: W m-2
#   long_name: Global Solar Radiation 10 Min Minimum
# qgx Attributes:
#   standard_name: global_solar_radiation
#   units: W m-2
#   long_name: Global Solar Radiation 10 Min Maximum
# qnh Attributes:
#   standard_name: qnh_1_min_average
#   units: hPa
#   long_name: QNH 1 Min Average
# R12H Attributes:
#   standard_name: rainfall_amount
#   units: mm
#   long_name: Rainfall in last 12 Hours
# R1H Attributes:
#   standard_name: rainfall_amount
#   units: mm
#   long_name: Rainfall in last Hour
# R24H Attributes:
#   standard_name: rainfall_amount
#   units: mm
#   long_name: Rainfall in last 24 Hours
# R6H Attributes:
#   standard_name: rainfall_amount
#   units: mm
#   long_name: Rainfall in last 6 Hours
# rg Attributes:
#   standard_name: precipitation_rate
#   units: mm h-1
#   long_name: Precipitation Intensity (Rain Gauge) 10 Min Average
# rh Attributes:
#   standard_name: relative_humidity
#   units: %
#   long_name: Relative Humidity 1.5m 1 Min Average
#   comment: Note: For some locations only rh10 is provided
# rh10 Attributes:
#   standard_name: relative_humidity
#   units: %
#   long_name: Relative Humidity 10 Min Average
#   comment: Note: For this variable the timestamp indicates the middle of the 10 Min interval
# Sav1H Attributes:
#   standard_name: wind_speed
#   units: m s-1
#   long_name: Wind Speed Average last 1 Hour
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sax1H Attributes:
#   standard_name: wind_speed
#   units: m s-1
#   long_name: Wind Speed Maximum last 1 Hour
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sax3H Attributes:
#   standard_name: wind_speed
#   units: m s-1
#   long_name: Wind Speed Maximum last 3 Hours
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sax6H Attributes:
#   standard_name: wind_speed
#   units: m s-1
#   long_name: Wind Speed Maximum last 6 Hours
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# sq Attributes:
#   standard_name: squall_indicator
#   units: code
#   long_name: Squall Indicator
#   comment: WMO table 4680
# ss Attributes:
#   standard_name: duration_of_sunshine
#   units: min
#   long_name: Sunshine Duration
# Sx1H Attributes:
#   standard_name: wind_gust
#   units: m s-1
#   long_name: Wind Gust Maximum last 1 Hour
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sx3H Attributes:
#   standard_name: wind_gust
#   units: m s-1
#   long_name: Wind Gust Maximum last 3 Hours
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sx6H Attributes:
#   standard_name: wind_gust
#   units: m s-1
#   long_name: Wind Gust Maximum last 6 Hours
#   comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# t10 Attributes:
#   standard_name: ambient_temperature_10_min_average
#   units: degrees Celsius
#   long_name: Ambient Temperature 10 Min Average
#   comment: Note: for this variable the timestamp indicates the middle of the 10 Min interval
# ta Attributes:
#   standard_name: air_temperature
#   units: degrees Celsius
#   long_name: Ambient Temperature 1.5m 10 Min Average
#   comment: Note: For some locations only t10 is provided
# tb Attributes:
#   standard_name: wet_bulb_temperature
#   units: degrees Celsius
#   long_name: Wet Bulb Temperature 1.5m 10 Min Average
# tb1 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -5cm 10 Min Average
# Tb1n6 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -5cm Minimum last 6 Hours
# Tb1x6 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -5cm Maximum last 6 Hours
# tb2 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -10cm 10 Min Average
# Tb2n6 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -10cm Minimum last 6 Hours
# Tb2x6 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -10cm Maximum last 6 Hours
# tb3 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -20cm 10 Min Average
# tb4 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -50cm 10 Min Average
# tb5 Attributes:
#   standard_name: soil_temperature
#   units: degrees Celsius
#   long_name: Soil Temperature -100cm 10 Min Average
# td Attributes:
#   standard_name: dew_point_temperature
#   units: degrees Celsius
#   long_name: Dew Point Temperature 1.5m 1 Min Average
#   comment: Note: For some locations only td10 is provided
# td10 Attributes:
#   standard_name: dew_point_temperature
#   units: degrees Celsius
#   long_name: Dew Point Temperature 10 Min Average
#   comment: Note: for this variable the timestamp indicates the middle of the 10 Min interval
# tg Attributes:
#   standard_name: air_temperature
#   units: degrees Celsius
#   long_name: Grass Temperature 10cm 10 Min Average
# tgn Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Grass Temperature 10cm 10 Min Minimum
# Tgn12 Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Grass Temperature Minimum last 12 Hours
# Tgn14 Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Grass Temperature Minimum last 14 Hours
# Tgn6 Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Grass Temperature Minimum last 6 Hours
# tn Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Ambient Temperature 1.5m 10 Min Minimum
# Tn12 Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Air Temperature Minimum last 12 Hours
# Tn14 Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Air Temperature Minimum last 14 Hours
# Tn6 Attributes:
#   standard_name: air_temperature_minimum
#   units: degrees Celsius
#   long_name: Air Temperature Minimum last 6 Hours
# tsd Attributes:
#   standard_name: siam_ambient_temperature_10_min_average_std_dev
#   units: degrees Celsius
#   long_name: SIAM Ambient Temperature 10 Min Average Std Dev
# tx Attributes:
#   standard_name: air_temperature_maximum
#   units: degrees Celsius
#   long_name: Ambient Temperature 1.5m 10 Min Maximum
# Tx12 Attributes:
#   standard_name: air_temperature_maximum
#   units: degrees Celsius
#   long_name: Air Temperature Maximum last 12 Hours
# Tx24 Attributes:
#   standard_name: air_temperature_maximum
#   units: degrees Celsius
#   long_name: Air Temperature Maximum last 24 Hours
# Tx6 Attributes:
#   standard_name: air_temperature_maximum
#   units: degrees Celsius
#   long_name: Air Temperature Maximum last 6 Hours
# vv Attributes:
#   standard_name: visibility
#   units: m
#   long_name: Horizontal Visibility 10 Min Average
#   comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# W10 Attributes:
#   standard_name: past_weather_indicator
#   units: code
#   long_name: Past Weather Indicator
#   comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# W10-10 Attributes:
#   standard_name: past_weather_indicator
#   units: code
#   long_name: Past Weather Indicator for Previous 10 Min Interval
#   comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# ww Attributes:
#   standard_name: wawa_weather_code
#   units: code
#   long_name: wawa Weather Code
#   comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# ww-10 Attributes:
#   standard_name: wawa_weather_code
#   units: code
#   long_name: wawa Weather Code for Previous 10 Min Interval
#   comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# zm Attributes:
#   standard_name: visibility_in_air
#   units: m
#   long_name: Meteorological Optical Range 10 Min Average
#   comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# iso_dataset Attributes:
#   title: KMDS__OPER_P___10M_OBS_L2
#   abstract: Most recent 10 minute in situ observations of the Dutch meteorological observation network
#   status: ongoing
#   type: dataset
#   uid: c3a312e2-2d8f-440b-ae7d-3406c9fe2f77
#   topic: climatology, meteorology, atmosphere
#   keyword: temperature, pressure, relative humidity, visibility, wind speed, wind direction, wind gust
#   max-x: 7.400000095367432
#   min-x: -68.5
#   max-y: 55.70000076293945
#   min-y: 12.0
#   temporal_extent: 1950-01-01 and ongoing
#   date: 2023-07-01
#   dateType: publication date
#   statement: KNMI collects observations from automatic weather stations situated in the Netherlands and BES islands on locations such as aerodromes and North Sea platforms. In addition, wind data from 5 KNMI wind poles are included. The weather stations report every 10 minutes meteorological parameters such as temperature, relative humidity, wind, air pressure, visibility, precipitation and cloud cover. The number of parameters differs per station.
#   code: 4326
#   codeSpace: EPSG
#   accessConstraints: No limitations
#   useLimitation: No use limitations
#   organisationName_dataset: Royal Netherlands Meteorological Institute (KNMI)
#   email_dataset: opendata@knmi.nl
#   role_dataset: pointOfContact
#   metadata_id: 0ebaef73-6bff-4a25-a86b-6bf53bc4c505
#   organisationName_metadata: Royal Netherlands Meteorological Institute (KNMI)
#   role_metadata: pointOfContact
#   email_metadata: opendata@knmi.nl
#   url_metadata: https://dataplatform.knmi.nl
#   datestamp: 2014-07-23
#   language: eng
#   metadataStandardName: ISO 19115
#   metadataStandardNameVersion: Nederlandse metadatastandaard op ISO 19115 voor geografie 1.2
# product Attributes:
#   units: 1
#   long_name: ADAGUC Data Products Standard
#   ref_doc: ADAGUC Data Products Standard
#   ref_doc_version: 1.1
#   format_version: 1.1
#   originator: Royal Netherlands Meteorological Institute (KNMI)
#   type: P
#   acronym: KMDS__OPER_P___10M_OBS_L2
#   level: L2
#   style: camelCase
# projection Attributes:
#   EPSG_code: EPSG:4326
# nhc Attributes:
#   standard_name: low_and_middle_cloud_amount_ceilometer
#   units: octa
#   long_name: Low and Middle Cloud Amount Ceilometer
# za Attributes:
#   standard_name: background_luminance
#   units: cd m-2
#   long_name: Background Luminance 10 Min Average
#   comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#
# Encoding:
# station Encoding: {'dtype': dtype('<U5')}
# time Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (1,), 'preferred_chunks': {'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (1,), 'units': 'seconds since 1950-01-01 00:00:00'}
# wsi Encoding: {'dtype': dtype('<U15')}
# stationname Encoding: {'dtype': dtype('<U36')}
# lat Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69,), 'preferred_chunks': {'station': 69}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69,)}
# lon Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69,), 'preferred_chunks': {'station': 69}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69,)}
# height Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69,), 'preferred_chunks': {'station': 69}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69,)}
# D1H Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# dd Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# dn Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# dr Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# dsd Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# dx Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# ff Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# ffs Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# fsd Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# fx Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# fxs Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# gff Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# gffs Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# h Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# h1 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# h2 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# h3 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# hc Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# ...
# Sx6H Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# t10 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# ta Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tb Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tb1 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tb1n6 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tb1x6 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tb2 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tb2n6 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tb2x6 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tb3 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tb4 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tb5 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# td Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# td10 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tg Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tgn Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tgn12 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tgn14 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tgn6 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tn Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tn12 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tn14 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tn6 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tsd Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# tx Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tx12 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tx24 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# Tx6 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# vv Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# W10 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# W10-10 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# ww Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# ww-10 Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# zm Encoding: {'dtype': dtype('float64'), 'zlib': True, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': True, 'complevel': 2, 'fletcher32': False, 'contiguous': False, 'chunksizes': (69, 1), 'preferred_chunks': {'station': 69, 'time': 1}, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': (69, 1), '_FillValue': -9999.0}
# iso_dataset Encoding: {'dtype': dtype('S1'), 'zlib': False, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': False, 'complevel': 0, 'fletcher32': False, 'contiguous': True, 'chunksizes': None, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': ()}
# product Encoding: {'dtype': dtype('S1'), 'zlib': False, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': False, 'complevel': 0, 'fletcher32': False, 'contiguous': True, 'chunksizes': None, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': ()}
# projection Encoding: {'dtype': dtype('S1'), 'zlib': False, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': False, 'complevel': 0, 'fletcher32': False, 'contiguous': True, 'chunksizes': None, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': ()}
# nhc Encoding: {'dtype': dtype('S1'), 'zlib': False, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': False, 'complevel': 0, 'fletcher32': False, 'contiguous': True, 'chunksizes': None, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': ()}
# za Encoding: {'dtype': dtype('S1'), 'zlib': False, 'szip': False, 'zstd': False, 'bzip2': False, 'blosc': False, 'shuffle': False, 'complevel': 0, 'fletcher32': False, 'contiguous': True, 'chunksizes': None, 'source': '/home/manuel/Projects/EnergySaver/data/KMDS__OPER_P___10M_OBS_L2_202402132020.nc', 'original_shape': ()}

# %%
# Check the number of numerical and categorical variables
num_vars = df.select_dtypes(include=['float64', 'int64']).columns
cat_vars = df.select_dtypes(include=['object']).columns

print(f"\nNumber of numerical variables: {len(num_vars)}")
print(f"Number of categorical variables: {len(cat_vars)}")

# Check for each of the categorical variables, the number of unique values and print them
print("\nUnique values for categorical variables:")
for var in cat_vars:
    print(f"{var}: {df[var].nunique()} unique values")
    print(df[var].unique())
# Out:
# Number of numerical variables: 94
# Number of categorical variables: 7
#
# Unique values for categorical variables:
# wsi: 69 unique values
# ['0-20000-0-06201' '0-20000-0-06203' '0-20000-0-06204' '0-20000-0-06205'
#  '0-20000-0-06207' '0-20000-0-06208' '0-20000-0-06209' '0-20000-0-06211'
#  '0-20000-0-06214' '0-20000-0-06215' '0-528-0-06216' '0-20000-0-06225'
#  '0-20000-0-06229' '0-528-0-06233' '0-20000-0-06235' '0-528-0-06236'
#  '0-528-0-06237' '0-528-0-06238' '0-20000-0-06239' '0-20000-0-06240'
#  '0-20000-0-06242' '0-20000-0-06248' '0-20000-0-06249' '0-20000-0-06251'
#  '0-20000-0-06252' '0-20000-0-06257' '0-20000-0-06258' '0-20000-0-06260'
#  '0-20000-0-06267' '0-20000-0-06269' '0-20000-0-06270' '0-20000-0-06273'
#  '0-20000-0-06275' '0-20000-0-06277' '0-20000-0-06278' '0-20000-0-06279'
#  '0-20000-0-06280' '0-20000-0-06283' '0-20000-0-06285' '0-20000-0-06286'
#  '0-20000-0-06290' '0-20000-0-06308' '0-20000-0-06310' '0-20000-0-06312'
#  '0-20000-0-06313' '0-20000-0-06315' '0-20000-0-06316' '0-528-0-06317'
#  '0-20000-0-06319' '0-20000-0-06320' '0-20000-0-06321' '0-20000-0-06323'
#  '0-20000-0-06324' '0-20000-0-06330' '0-20000-0-06331' '0-20000-0-06340'
#  '0-20000-0-06343' '0-20000-0-06344' '0-20000-0-06348' '0-20000-0-06350'
#  '0-20000-0-06356' '0-20000-0-06370' '0-20000-0-06375' '0-20000-0-06377'
#  '0-20000-0-06380' '0-20000-0-06391' '0-20000-0-78871' '0-20000-0-78873'
#  '0-20000-0-78990']
# stationname: 69 unique values
# ['D15-FA-1' 'P11-B' 'K14-FA-1C' 'A12-CPP' 'L9-FF-1' 'AWG-1' 'IJMOND WP'
#  'J6-A' 'BG-OHVS2' 'VOORSCHOTEN AWS' 'Hollandse Kust Zuid Alfa (HKZA)'
#  'IJMUIDEN WP' 'TEXELHORS WP' 'Assendelft BTP' 'DE KOOY VK' 'Muiden BTP'
#  'Nieuw Vennep BTP' 'Nieuwkoop BTP' 'F3-FB-1' 'AMSTERDAM/SCHIPHOL AP'
#  'VLIELAND' 'WIJDENES WP' 'BERKHOUT AWS' 'TERSCHELLING HOORN AWS' 'K13-A'
#  'WIJK AAN ZEE AWS' 'HOUTRIBDIJK WP' 'DE BILT AWS' 'STAVOREN AWS'
#  'LELYSTAD AP' 'LEEUWARDEN' 'MARKNESSE AWS' 'DEELEN' 'LAUWERSOOG AWS'
#  'HEINO AWS' 'HOOGEVEEN AWS' 'GRONINGEN AP EELDE' 'HUPSEL AWS'
#  'HUIBERTGAT WP' 'NIEUW BEERTA AWS' 'TWENTHE AWS' 'CADZAND WP'
#  'VLISSINGEN AWS' 'OOSTERSCHELDE WP' 'VLAKTE VAN DE RAAN' 'HANSWEERT'
#  'OOSTERSCHELDE 4' 'BORSSELE ALFA (BSA)' 'WESTDORPE AWS'
#  'LICHTEILAND GOEREE' 'EURO PLATFORM' 'WILHELMINADORP AWS' 'STAVENISSE'
#  'HOEK VAN HOLLAND AWS' 'MAROLLEGAT' 'WOENSDRECHT' 'ROTTERDAM GEULHAVEN'
#  'ROTTERDAM THE HAGUE AP' 'CABAUW TOWER AWS' 'GILZE RIJEN' 'HERWIJNEN AWS'
#  'EINDHOVEN AP' 'VOLKEL' 'ELL AWS' 'MAASTRICHT AACHEN AP' 'ARCEN AWS'
#  'JUANCHO E. YRAUSQUIN AIRPORT SABA'
#  'F.D. ROOSEVELT AIRPORT ST. EUSTATIUS' 'FLAMINGO AIRPORT BONAIRE']
# iso_dataset: 1 unique values
# [b'']
# product: 1 unique values
# [b'']
# projection: 1 unique values
# [b'']
# nhc: 1 unique values
# [b'']
# za: 1 unique values
# [b'']

# %%
# Filter out only the columns where the station name has "EINDHOVEN" in it
eindhoven_df = df[df['stationname'].str.contains('EINDHOVEN')]

print(eindhoven_df.head())
# Out:
#                                          wsi   stationname      lat     lon  \
# station time
# 06370   2024-02-13 20:20:00  0-20000-0-06370  EINDHOVEN AP  51.4497  5.3769
#
#                              height  D1H     dd     dn   dr   dsd  ...  W10  \
# station time                                                       ...
# 06370   2024-02-13 20:20:00   20.69  0.0  179.8  149.1  0.0  10.9  ...  0.0
#
#                              W10-10    ww  ww-10       zm  iso_dataset  \
# station time
# 06370   2024-02-13 20:20:00     0.0  22.0   22.0  48900.0          b''
#
#                              product  projection  nhc   za
# station time
# 06370   2024-02-13 20:20:00      b''         b''  b''  b''
#
# [1 rows x 101 columns]
